# %% [markdown]
# <a href="https://colab.research.google.com/github/fivetop/python/blob/master/TF_2_x_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Flatten, Dense, Input
from tensorflow.keras.optimizers import SGD

import numpy as np

# %%
x_data = np.array([1,2,3,4,5,6])
t_data = np.array([3,4,5,6,7,8])

# %%
model = Sequential()

model.add(Flatten(input_shape=(1,)))

#model.add(Dense(1, activation='linear'))

model.add(Dense(1))

#model.add(Dense(1, input_shape(1,), activation='linear'))

# %%
print(model.weights)
# Out:
# [<tf.Variable 'dense_5/kernel:0' shape=(1, 1) dtype=float32, numpy=array([[-1.236498]], dtype=float32)>, <tf.Variable 'dense_5/bias:0' shape=(1,) dtype=float32, numpy=array([0.], dtype=float32)>]

# %%
model.compile(optimizer=SGD(), loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_5 (Flatten)         (None, 1)                 0
#
#  dense_5 (Dense)             (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_data, t_data,   epochs=200)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 248ms/step - loss: 111.1735
# Epoch 2/200
# 1/1 [==============================] - 0s 11ms/step - loss: 51.6546
# Epoch 3/200
# 1/1 [==============================] - 0s 10ms/step - loss: 24.1060
# Epoch 4/200
# 1/1 [==============================] - 0s 9ms/step - loss: 11.3543
# Epoch 5/200
# 1/1 [==============================] - 0s 9ms/step - loss: 5.4509
# Epoch 6/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.7173
# Epoch 7/200
# 1/1 [==============================] - 0s 211ms/step - loss: 1.4506
# Epoch 8/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8630
# Epoch 9/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5896
# Epoch 10/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4617
# Epoch 11/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4011
# Epoch 12/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3717
# ...

# %%
hist = model.fit(x_data, t_data, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 325ms/step - loss: 1.7986
# Epoch 2/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 1.2166
# Epoch 3/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.9445
# Epoch 4/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.8157
# Epoch 5/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7534
# Epoch 6/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7218
# Epoch 7/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7044
# Epoch 8/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6937
# Epoch 9/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6861
# Epoch 10/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6799
# Epoch 11/1000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6744
# Epoch 12/1000
# ...

# %%
print(model.weights)
# Out:
# [<tf.Variable 'dense_2/kernel:0' shape=(1, 1) dtype=float32, numpy=array([[1.0117122]], dtype=float32)>, <tf.Variable 'dense_2/bias:0' shape=(1,) dtype=float32, numpy=array([1.949858], dtype=float32)>]

# %%
test_input_data = np.array([-3.1, 3.0, 3.5, 15.0, 20.1])
label_data =test_input_data + 2.0

result = model.predict(test_input_data)

print(result.shape)

print(result)
print(label_data, np.reshape(5,1))
# Out:
# (5, 1)
# [[-2.2627368]
#  [ 4.798177 ]
#  [ 5.3769403]
#  [18.6885   ]
#  [24.591887 ]]
# [-1.1  5.   5.5 17.  22.1] [5]
